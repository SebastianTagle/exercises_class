# %%
import pandas as pd
import pathlib as Path

# %%
data="C:/Users/sebat/ClassRepository/exercises_class/Untitled Folder/Class 2/census_data_2016-2019.csv"

# %%
data_file = pd.read_csv(data)
data_file.head()
# Out:
#    Year          County    State  Population  Median Age  Household Income  \
# 0  2016  Autauga County  Alabama       55049        37.8           53099.0
# 1  2016  Baldwin County  Alabama      199510        42.3           51365.0
# 2  2016  Barbour County  Alabama       26614        38.7           33956.0
# 3  2016     Bibb County  Alabama       22572        40.2           39776.0
# 4  2016   Blount County  Alabama       57704        40.8           46212.0
#
#    Per Capita Income  Employed Civilians  Unemployed Civilians  \
# 0            26168.0             24262.0                1437.0
# 1            28069.0             87753.0                5887.0
# 2            17249.0              8993.0                1323.0
# 3            18988.0              8354.0                 643.0
# 4            21033.0             21593.0                1367.0
#
#    People in the Military  Poverty Count
# 0                   309.0         6697.0
# 1                   232.0        25551.0
# ...

# %%
data_df=pd.DataFrame(data_file)
data_census_df = data_df[["Year", "County", "State", "Population","Employed Civilians","Unemployed Civilians", "People in the Military", "Poverty Count"]]
data_census_df.head()
# Out:
#    Year          County    State  Population  Employed Civilians  \
# 0  2016  Autauga County  Alabama       55049             24262.0
# 1  2016  Baldwin County  Alabama      199510             87753.0
# 2  2016  Barbour County  Alabama       26614              8993.0
# 3  2016     Bibb County  Alabama       22572              8354.0
# 4  2016   Blount County  Alabama       57704             21593.0
#
#    Unemployed Civilians  People in the Military  Poverty Count
# 0                1437.0                   309.0         6697.0
# 1                5887.0                   232.0        25551.0
# 2                1323.0                     0.0         6235.0
# 3                 643.0                     5.0         3390.0
# 4                1367.0                     9.0         9441.0

# %%
census_group =data_census_df.groupby(["Year","State"])
census_group_df= census_group.sum()
census_group_df
# Out:
#                                                                County  \
# Year State
# 2016 Alabama        Autauga CountyBaldwin CountyBarbour CountyBibb...
#      Alaska         Aleutians East BoroughAleutians West Census Ar...
#      Arizona        Apache CountyCochise CountyCoconino CountyGila...
#      Arkansas       Arkansas CountyAshley CountyBaxter CountyBento...
#      California     Alameda CountyAlpine CountyAmador CountyButte ...
# ...                                                               ...
# 2019 Virginia       Accomack CountyAlbemarle CountyAlleghany Count...
#      Washington     Adams CountyAsotin CountyBenton CountyChelan C...
#      West Virginia  Barbour CountyBerkeley CountyBoone CountyBraxt...
#      Wisconsin      Adams CountyAshland CountyBarron CountyBayfiel...
#      Wyoming        Albany CountyBig Horn CountyCampbell CountyCar...
#
#                     Population  Employed Civilians  Unemployed Civilians  \
# Year State
# ...

# %%
census_group_df=census_group_df.rename(columns={"Population":"Total Population",
                                                "Employed Civilians":"Total Employed Civilians",
                                                "Unemployed Civilians": "Total Unemployed Civilians",
                                                "People in the Military": "Total People in the Military",
                                                "Poverty Count":"Total Poverty Count"})
census_group_df
# Out:
#                                                                County  \
# Year State
# 2016 Alabama        Autauga CountyBaldwin CountyBarbour CountyBibb...
#      Alaska         Aleutians East BoroughAleutians West Census Ar...
#      Arizona        Apache CountyCochise CountyCoconino CountyGila...
#      Arkansas       Arkansas CountyAshley CountyBaxter CountyBento...
#      California     Alameda CountyAlpine CountyAmador CountyButte ...
# ...                                                               ...
# 2019 Virginia       Accomack CountyAlbemarle CountyAlleghany Count...
#      Washington     Adams CountyAsotin CountyBenton CountyChelan C...
#      West Virginia  Barbour CountyBerkeley CountyBoone CountyBraxt...
#      Wisconsin      Adams CountyAshland CountyBarron CountyBayfiel...
#      Wyoming        Albany CountyBig Horn CountyCampbell CountyCar...
#
#                     Total Population  Total Employed Civilians  \
# Year State
# ...
