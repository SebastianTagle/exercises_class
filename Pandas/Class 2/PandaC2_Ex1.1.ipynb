# %%
import pandas as pd 
import pathlib as Path

# %%
dataset= "C:/Users/sebat/ClassRepository/exercises_class/PANDAS/Class 2/movie_scores.csv"

# %%
data_file = pd.read_csv(dataset)
data_file.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
#con esto, me muestras las columnas que tengo
data_file.columns
# Out:
# Index(['FILM', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Metacritic_user_vote_count', 'IMDB_user_vote_count',
#        'Fandango_votes', 'Fandango_Difference'],
#       dtype='object')

# %%
data_file.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Fandango_Stars  Fandango_Ratingvalue     RT_norm  \
# count  146.000000      146.000000            146.000000  146.000000
# mean     6.736986        4.089041              3.845205    3.042466
# std      0.958736        0.540386              0.502831    1.508440
# ...

# %%
data_file_filtro=data_file[["FILM","IMDB","IMDB_norm","IMDB_norm_round","IMDB_user_vote_count"]]
data_file_filtro=data_file_filtro.set_index("FILM")
data_file_filtro.head()
# Out:
#                                 IMDB  IMDB_norm  IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)   7.8       3.90              4.0
# Cinderella (2015)                7.1       3.55              3.5
# Ant-Man (2015)                   7.8       3.90              4.0
# Do You Believe? (2015)           5.4       2.70              2.5
# Hot Tub Time Machine 2 (2015)    5.1       2.55              2.5
#
#                                 IMDB_user_vote_count
# FILM
# Avengers: Age of Ultron (2015)                271107
# Cinderella (2015)                              65709
# Ant-Man (2015)                                103660
# Do You Believe? (2015)                          3136
# Hot Tub Time Machine 2 (2015)                  19560

# %%
#hay que referirlo al primer archivo.
dataf_filtro_2=data_file.loc[data_file["IMDB"]>7,["FILM","IMDB","IMDB_user_vote_count"]]
dataf_filtro_2.head()
# Out:
#                              FILM  IMDB  IMDB_user_vote_count
# 0  Avengers: Age of Ultron (2015)   7.8                271107
# 1               Cinderella (2015)   7.1                 65709
# 2                  Ant-Man (2015)   7.8                103660
# 5        The Water Diviner (2015)   7.2                 39373
# 8    Shaun the Sheep Movie (2015)   7.4                 12227

# %%
dataf_filtro_3=dataf_filtro_2.loc[dataf_filtro_2["IMDB_user_vote_count"]<20000,["FILM","IMDB","IMDB_user_vote_count"]]
dataf_filtro_3.head()
# Out:
#                                  FILM  IMDB  IMDB_user_vote_count
# 8        Shaun the Sheep Movie (2015)   7.4                 12227
# 9                 Love & Mercy (2015)   7.8                  5367
# 10  Far From The Madding Crowd (2015)   7.2                 12129
# 20              McFarland, USA (2015)   7.5                 13769
# 29         The End of the Tour (2015)   7.9                  1320

# %%
dataf_filtro_3.to_csv("C:/Users/sebat/ClassRepository/exercises_class/PANDAS/Class 2/unknown_movies.csv",index=False)

# %%
dataf_filtro_3.to_excel("C:/Users/sebat/ClassRepository/exercises_class/PANDAS/Class 2/unk_moviesx.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dataf_filtro_3.to_excel("C:/Users/sebat/ClassRepository/exercises_class/PANDAS/Class 2/unk_moviesx.xlsx",index=False)
#
# File c:\Users\sebat\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2252, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2239 from pandas.io.formats.excel import ExcelFormatter
#    2241 formatter = ExcelFormatter(
#    2242     df,
#    2243     na_rep=na_rep,
#    (...)
#    2250     inf_rep=inf_rep,
#    2251 )
# -> 2252 formatter.write(
#    2253     excel_writer,
#    2254     sheet_name=sheet_name,
#    2255     startrow=startrow,
#    2256     startcol=startcol,
# ...
